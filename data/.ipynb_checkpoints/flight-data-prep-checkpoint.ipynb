# %%
import pandas as pd
df = pd.read_csv("../data/trips.csv")
df['origin_coordinates'] = 'temp'
df['destination_coordinates'] = 'temp'

# %%
# for x in range(0,df.shape[0]):
#     df['origin'][x] = (df['origin'][x] + ' Airport')
#     df['destination'][x] = (df['destination'][x] + ' Airport')

df
# Out:
#         date                                 origin  \
# 0    2/24/17                 Seattle-Tacoma Airport
# 1    2/26/17                        Oakland Airport
# 2    2/26/17                      San Diego Airport
# 3    3/19/17                  San Francisco Airport
# 4    3/19/17                 Seattle-Tacoma Airport
# 5    6/13/17                 Seattle-Tacoma Airport
# 6    6/13/17              Charlotte Douglas Airport
# 7    6/23/17       Luis Munoz International Airport
# 8    6/23/17            Miami International Airport
# 9    6/26/17                    Havana Cuba Airport
# 10   6/26/17              Charlotte Douglas Airport
# 11    7/6/17                 Seattle-Tacoma Airport
# 12   7/10/17                  San Francisco Airport
# 13   7/20/17                 Seattle-Tacoma Airport
# 14   7/24/17  John F. Kennedy International Airport
# 15   10/6/17                 Seattle-Tacoma Airport
# 16   10/8/17                  San Francisco Airport
# 17  10/22/17                 Seattle-Tacoma Airport
# 18  10/23/17                      Frankfurt Airport
# 19  10/28/17                           Berlin Tegel
# 20  10/28/17                      Frankfurt Airport
# 21  11/22/17                 Seattle-Tacoma Airport
# 22  11/27/17                  San Francisco Airport
# 23  11/27/17                    Los Angeles Airport
# 24  11/30/17                        Oakland Airport
# 25  12/12/17                 Seattle-Tacoma Airport
# 26  12/13/17                        London Heathrow
# 27  12/16/17                      Berlin Sch_nefeld
# 28  12/18/17           Athens International Airport
# 29  12/21/17            Interrent Santorini Airport
# 30  12/21/17           Athens International Airport
# 31  12/24/17          Ataturk International Airport
# 32  12/25/17       Ben Gurien International Airport
# 33  12/27/17                  San Francisco Airport
# 34    1/6/18                 Seattle-Tacoma Airport
# 35   1/12/18                      Las Vegas Airport
# 36   1/21/18                 Seattle-Tacoma Airport
# 37   1/27/18                        Schipol Airport
# 38   1/28/18                 Seattle-Tacoma Airport
# 39   1/31/18                 Chicago O'Hare Airport
# 40   3/10/18                 Seattle-Tacoma Airport
# 41   3/15/18                      Frankfurt Airport
# 42   3/16/18                 Seattle-Tacoma Airport
# 43   3/22/18                         Cancun Airport
# 44   3/22/18                         Denver Airport
# 45   5/10/18                 Seattle-Tacoma Airport
# 46   5/13/18                         Denver Airport
# 47   5/15/18                 Seattle-Tacoma Airport
# 48   5/17/18                  San Francisco Airport
# 49   5/22/18                 Seattle-Tacoma Airport
# 50   5/24/18                 Chicago O'Hare Airport
# 51    30-May                 Seattle-Tacoma Airport
# 52   5/31/18                      Frankfurt Airport
# 53    6/2/18              Barcelona El Prat Airport
# 54    6/7/18                        Mykonos Airport
# 55    6/9/18           Athens International Airport
# 56    6/9/18                      Frankfurt Airport
#
#                               destination           airline      type  \
# 0                       San Diego Airport         Southwest  Personal
# 1                  Seattle-Tacoma Airport         Southwest  Personal
# 2                         Oakland Airport         Southwest  Personal
# 3                  Cabo San Lucas Airport            United  Personal
# 4                   San Francisco Airport            United  Personal
# 5               Charlotte Douglas Airport          American  Personal
# 6        Luis Munoz International Airport          American  Personal
# 7             Miami International Airport          American  Personal
# 8                     Havana Cuba Airport          American  Personal
# 9               Charlotte Douglas Airport          American  Personal
# 10                 Seattle-Tacoma Airport          American  Personal
# 11                  San Francisco Airport            Alaska  Personal
# 12                 Seattle-Tacoma Airport            Alaska  Personal
# 13  John F. Kennedy International Airport            Alaska  Personal
# 14                 Seattle-Tacoma Airport            Alaska  Personal
# 15                  San Francisco Airport            United  Personal
# 16                 Seattle-Tacoma Airport            United  Personal
# 17                      Frankfurt Airport         Lufthansa      Work
# 18                           Berlin Tegel         Lufthansa      Work
# 19                      Frankfurt Airport         Lufthansa      Work
# 20                 Seattle-Tacoma Airport         Lufthansa      Work
# 21                  San Francisco Airport            Alaska      Work
# 22                    Los Angeles Airport    Virgin America      Work
# 23                  San Francisco Airport    Virgin America      Work
# 24                 Seattle-Tacoma Airport         Southwest      Work
# 25                        London Heathrow   British Airways      Work
# 26                           Berlin Tegel   British Airways      Work
# 27           Athens International Airport           Ryanair  Personal
# 28            Interrent Santorini Airport       Olympic Air  Personal
# 29           Athens International Airport       Olympic Air  Personal
# 30          Ataturk International Airport  Turkish Airlines      Work
# 31       Ben Gurien International Airport  Turkish Airlines      Work
# 32                  San Francisco Airport            United      Work
# 33                 Seattle-Tacoma Airport            Alaska  Personal
# 34                      Las Vegas Airport            Alaska      Work
# 35                 Seattle-Tacoma Airport            Alaska      Work
# 36                        Schipol Airport             Delta      Work
# 37                 Seattle-Tacoma Airport             Delta      Work
# 38                 Chicago O'Hare Airport            Alaska      Work
# 39                 Seattle-Tacoma Airport            Alaska      Work
# 40                      Frankfurt Airport         Lufthansa      Work
# 41                 Seattle-Tacoma Airport         Lufthansa      Work
# 42                         Cancun Airport             Delta  Personal
# 43                         Denver Airport            United  Personal
# 44                 Seattle-Tacoma Airport            United  Personal
# 45                         Denver Airport            Alaska  Personal
# 46                 Seattle-Tacoma Airport            Alaska  Personal
# 47                  San Francisco Airport            Alaska      Work
# 48                 Seattle-Tacoma Airport            Alaska      Work
# 49                 Chicago O'Hare Airport            Alaska      Work
# 50                 Seattle-Tacoma Airport            Alaska      Work
# 51                      Frankfurt Airport         Lufthansa  Personal
# 52              Barcelona El Prat Airport         Lufthansa  Personal
# 53                        Mykonos Airport           Vueling  Personal
# 54           Athens International Airport       Olympic Air  Personal
# 55                      Frankfurt Airport         Lufthansa  Personal
# 56                 Seattle-Tacoma Airport         Lufthansa  Personal
#
#    origin_coordinates destination_coordinates
# 0                temp                    temp
# 1                temp                    temp
# 2                temp                    temp
# 3                temp                    temp
# 4                temp                    temp
# 5                temp                    temp
# 6                temp                    temp
# 7                temp                    temp
# 8                temp                    temp
# 9                temp                    temp
# 10               temp                    temp
# 11               temp                    temp
# 12               temp                    temp
# 13               temp                    temp
# 14               temp                    temp
# 15               temp                    temp
# 16               temp                    temp
# 17               temp                    temp
# 18               temp                    temp
# 19               temp                    temp
# 20               temp                    temp
# 21               temp                    temp
# 22               temp                    temp
# 23               temp                    temp
# 24               temp                    temp
# 25               temp                    temp
# 26               temp                    temp
# 27               temp                    temp
# 28               temp                    temp
# 29               temp                    temp
# 30               temp                    temp
# 31               temp                    temp
# 32               temp                    temp
# 33               temp                    temp
# 34               temp                    temp
# 35               temp                    temp
# 36               temp                    temp
# 37               temp                    temp
# 38               temp                    temp
# 39               temp                    temp
# 40               temp                    temp
# 41               temp                    temp
# 42               temp                    temp
# 43               temp                    temp
# 44               temp                    temp
# 45               temp                    temp
# 46               temp                    temp
# 47               temp                    temp
# 48               temp                    temp
# 49               temp                    temp
# 50               temp                    temp
# 51               temp                    temp
# 52               temp                    temp
# 53               temp                    temp
# 54               temp                    temp
# 55               temp                    temp
# 56               temp                    temp

# %%
from urllib2 import Request, urlopen, URLError, HTTPError
import json
hereId = "uHmohQEsYnwhA4FGz1Jw"
hereCode = "hKz7JnGqtqj5UECMSBqDHw"

global i
i= 0
def place(search_value):
    search_value = search_value.replace(" ", "+")
    base = "https://places.cit.api.here.com/places/v1/autosuggest?at=90.0000,-142.5048&q=" + search_value + "&app_id=" + hereId + "&app_code=" + hereCode
    global i
    i = i+1
    if search_value is "":
        return "null"
    else:
        request = Request(base)
        try:
            response = urlopen(request)
            read_response = response.read()
            data = json.loads(read_response)
            if data['results'] == []:
                coordinates_text = "null"
            else:
                coordinates_text = data['results'][0]['position']
                print "success"
            return coordinates_text 
        except HTTPError as e:
             print e.code
             print e.read()
             return "null"


print place("London Heathrow")
# Out:
# success
# [51.47244, -0.45288]

# %%
for x in range(0,df.shape[0]):
    df['origin_coordinates'][x] = place(df['origin'][x])
    df['destination_coordinates'][x] = place(df['destination'][x])
# Out:
# success

# %%
df

# %%
df = df.to_dict('records')

# %%
df

# %%
def coord(origin, desti):
    print origin
    print desti
    if ',' in origin and ',' in desti:
        one = [float(origin.split(',')[1]), float(origin.split(',')[0])]
        two = [float(desti.split(',')[1]), float(desti.split(',')[0])]
        return [one, two]
    else:
        return [origin, desti]

# %%
#swap lat long
for x in range(0,len(df)):
    df[x]['origin_coordinates'] = [df[x]['origin_coordinates'][1], df[x]['origin_coordinates'][0]]
    df[x]['destination_coordinates'] = [df[x]['destination_coordinates'][1], df[x]['destination_coordinates'][0]]

# %%
def distance(origin, destination):
    distance = (gpxpy.geo.haversine_distance(origin[1], origin[0], destination[1], destination[0])) * 0.000621371
    return distance

def flight_time(distance):
    avg_speed = 560 #mph
    return distance / avg_speed

# %%
layer = []
import gpxpy.geo
for x in range(0,len(df)):
    layer.append({
        "destination": df[x]['destination'],
        "origin": df[x]['origin'],
        "type": df[x]['type'],
        "airline": df[x]['airline'],
        "ports": [df[x]['destination'], df[x]['origin']],
        "date": df[x]['date'],
        "sourcePosition": df[x]['origin_coordinates'],
        "targetPosition": df[x]['destination_coordinates'],
        "distance": distance(df[x]['origin_coordinates'], df[x]['destination_coordinates']),
    })
  
geojson = {
    "type": "FeatureCollection",
    "features": []
}
for x in range(0,len(df)):
    geojson['features'].append({
        "geometry": {
            "type": "LineString",
            "coordinates": [df[x]['origin_coordinates'], df[x]['destination_coordinates']]
        },
        "properties": {
            "destination": df[x]['destination'],
            "origin": df[x]['origin'],
            "type": df[x]['type'],
            "airline": df[x]['airline'],
            "ports": [df[x]['destination'], df[x]['origin']],
            "date": df[x]['date'],
            "sourcePosition": df[x]['origin_coordinates'],
            "targetPosition": df[x]['destination_coordinates'],
            "distance": distance(df[x]['origin_coordinates'], df[x]['destination_coordinates'])
        },
        "type": "Feature"
    })
    

with open('../data/trips.json', 'w') as fp:
    json.dump(layer, fp)
with open('../data/trips.geojson', 'w') as fp:
    json.dump(geojson, fp)

# %% [markdown]
# ### to do:
# - distance calculations w/ turf
# - calculate time spent in each place with packed bubbles
# - total time flying
# - work vs personal filter
